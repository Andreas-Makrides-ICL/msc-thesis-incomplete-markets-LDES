# %%
import pandas as pd
import glob
import os

# Parameters
folder_path = 'clustered_data'  # Adjust to your folder path
output_capacity_file = 'concatenated_capacity_factors_40yr.csv'
output_load_file = 'concatenated_load_profiles_40yr.csv'
output_weights_file = 'concatenated_weights_40yr.csv'

# Function to concatenate files matching a pattern
def concatenate_files(file_pattern, output_file):
    # Find all files matching the pattern
    files = glob.glob(os.path.join(folder_path, file_pattern))
    if not files:
        print(f"No files found for pattern {file_pattern}")
        return
    
    # Read and concatenate all files
    df_list = []
    for file in files:
        df = pd.read_csv(file)
        df_list.append(df)
        print(f"Read {file} with shape {df.shape}")
    
    # Concatenate vertically
    concatenated_df = pd.concat(df_list, ignore_index=True)
    
    # Save to output file
    concatenated_df.to_csv(os.path.join(folder_path, output_file), index=False)
    print(f"Saved {output_file} with shape {concatenated_df.shape}")

# Concatenate capacity factors files
concatenate_files('capacity_factors_gen_clustered_672_*.csv', output_capacity_file)
# Concatenate load profiles files
concatenate_files('load_profile_clustered_672_*.csv', output_load_file)
# Concatenate weights files
concatenate_files('weights_clustered_672_*.csv', output_weights_file)
# Out:
# Read clustered_data\capacity_factors_gen_clustered_672_10_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_11_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_12_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_13_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_14_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_15_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_16_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_17_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_18_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_19_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_1_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_20_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_21_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_22_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_23_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_24_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_25_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_26_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_27_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_28_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_29_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_2_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_30_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_3_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_4_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_5_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_6_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_7_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_8_.csv with shape (672, 5)
# Read clustered_data\capacity_factors_gen_clustered_672_9_.csv with shape (672, 5)
# Saved concatenated_capacity_factors_40yr.csv with shape (20160, 5)
# Read clustered_data\load_profile_clustered_672_10_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_11_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_12_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_13_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_14_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_15_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_16_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_17_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_18_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_19_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_1_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_20_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_21_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_22_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_23_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_24_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_25_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_26_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_27_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_28_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_29_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_2_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_30_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_3_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_4_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_5_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_6_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_7_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_8_.csv with shape (672, 3)
# Read clustered_data\load_profile_clustered_672_9_.csv with shape (672, 3)
# Saved concatenated_load_profiles_40yr.csv with shape (20160, 3)
# Read clustered_data\weights_clustered_672_10_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_11_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_12_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_13_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_14_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_15_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_16_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_17_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_18_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_19_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_1_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_20_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_21_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_22_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_23_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_24_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_25_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_26_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_27_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_28_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_29_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_2_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_30_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_3_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_4_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_5_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_6_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_7_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_8_.csv with shape (672, 3)
# Read clustered_data\weights_clustered_672_9_.csv with shape (672, 3)
# Saved concatenated_weights_40yr.csv with shape (20160, 3)
